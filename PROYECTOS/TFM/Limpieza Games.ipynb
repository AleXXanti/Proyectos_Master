# %% [markdown]
# <div style="text-align: center">
# <h1><font color="black" size=8>GAMES</font></h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import pylab
import ast
from sklearn.preprocessing import MultiLabelBinarizer

# %% [markdown]
# En este dataframe se recogen 41.625 reviews en las cuales encontramos las siguientes variables:
#
# 1- **`id`**: número de identificación de cada videojuego recogido.
#
# 2- **`category`**: tipo de videjuego
#
# 3- **`first_release_date`**: fecha con la que salió el juego por primera vez al mercado
#
# 4- **`games_mode`**: los distintos modos que tiene el juego a analizar.
#
# 5- **`genres`**: género del videojuego
#
# 6- **`name`**: nombre del juego
#
# 7- **`platforms`**: plataformas en la que está disponible el videojuego.
#
# 8- **`player_perspectives`**: tipos de pespectiva en los que se puede jugar con el persosnaje.
#
# 9- **`summary`**: resumen del videojuego.
#
# 10- **`themes`**: temáticas del videojuego.
#
# 11- **`storyline`**: texto que cuenta la trama principal del videojuego.
#
# 12- **`status`**: situación en la que se encontraba el videojuego a la hora venderse.
#
# 13- **`age_ratings`**: características que tiene el videojuego a la hora de restringir la edad.
#
# 14- **`update_at`**: fecha de su ultima actualización.
#
# 15- **`developer`**: la empresa desarrolladora del videojuego.
#
# 16- **`porting`**: empresas que han porteado el juego a otras consolas que no fuesen las iniciales planteadas.
#
# 17- **`publisher`**: la empresa distribuidora del videojuego.
#
# 18- **`supporting`**: empresa que da soporte al juego una vez lanzado.
#
# 19- **`keywords`**: palabras clave a la hora de describir el videojuego.
#
# 20- **`games_engines`**: motor empleado para su desarrollo.
#
# 21- **`parent_game`**: indica características de ese videojuego heredadas de otros videojuegos de la misma saga.
#
# 22- **`releases_dates`**: fechas de su publicación en diferentes zonas geográficas.
#
# 23- **`remakes`**: indica si ese videojuego tiene un remake en otras cosolas.
#
# 24- **`remasters`**: indica si ese videojuego tiene un remaster en otras cosolas.
#
# 25- **`ports`**: indica si ese videojuego tiene un port en otras cosolas.
#
# 26- **`bundles`**: indica si ese videojuego venía o viene incluido en algún paquete que recoge varios videojuegos (a un precio rebajado).
#
# 27- **`standalone_expansions`**: expansión de un videojuego el cual se pueda jugar sin el juego base.
#
# 28- **`franchises`**: saga a la que pertenece un videojuego.
#
# 29- **`expanded_games`**: videojuegos que se lanzaron con anterioridad pero con todo el contenido extra incluido.
#
# 30- **`expansions`**: contenido adicional de un videojuego.
#
# 31- **`HLTB_name`**: nombre del videojuego en la página web HowLongToBeat.com
#
# 32- **`HLTB_link`**: enlace que lleva ese videojuego en la página web HowLongToBeat.com
#
# 33- **`main_duration`**: tiempo que te cuesta completar la historia principal base del juego (en horas).
#
# 34- **`extra_duration`**: tiempo que te cuesta completar el contenido adicional del juego (en horas).
#
# 35- **`comp_duration`**: tiempo que te cuesta completar el juego al 100% (en horas).
#
# 36- **`HLTB_equal_name`**: booleano que será True si el nombre en la página web HowLongToBeat coincide con el recogido en la variable `name`; siendo False en caso contrario.
#
# 37- **`OC_rating`**: valoración del videojuego dada en la página web OpenCritic. Va del 0 al 100 siendo 0 lo más bajo y 100 lo más alto.
#
# 38- **`OC_nreviews`**: número de reviews que ha tenido ese videojuego en la página web OpenCritic.
#
# 39- **`OC_name`**: nombre del videojuego en la página web OpenCritic.
#
# 40- **`OC_link`**: enlace que lleva ese videojuego en la página web OpenCritic.
#
# 41- **`n_count`**: número de reviews recogidas de ese videojuego.
#
# 42- **`RAWG_name`**: nombre del videojuego en la página web rawg.io.
#
# 43- **`RAWG_link`**: enlace que lleva ese videojuego en la página web rawg.io.
#
# 44- **`RAWG_equal_name`**:  booleano que será True si el nombre en la página web rawg.io coincide con el recogido en la variable `name`; siendo False en caso contrario.
#
# 45- **`MC_rating`**: valoración del videojuego dada en la página web MetaCritic. Va del 0 al 100 siendo 0 lo más bajo y 100 lo más alto..
#
# 46- **`MC_link`**: enlace que lleva ese videojuego en la página web MetaCritic.
#
# 47- **`RAWG_rating`**: valoración del videojuego dada en la página web rawg.io. Va del 0 al 5 siendo 0 lo más bajo y 5 lo más alto pero el 1 no tiene valor.
#
# 48- **`RAWG_nreviews`**: número de reviews que ha tenido ese videojuego en la página web rawg.io.
#
# 49- **`devs`**: nombre de las personas que han desarrolado el videojuego.
#
# 50- **`OC_equal_name`**:  booleano que será True si el nombre en la página web OpenCritic coincide con el recogido en la variable `name`; siendo False en caso contrario.
#
# 51- **`advanced_devs`**: nombre del desarrolador con información adicional de éste

# %% [markdown]
# Cargamos el dataset

# %%
# Cargamos el dataframe

games_df = pd.read_feather("C:/Users/ALEX/Desktop/Master/TFM/games.feather")
games_df.head()
# Out:
#       id   category   first_release_date  \
# 0   9888  main_game  2015-01-30 00:00:00
# 1   9888  main_game  2015-01-30 00:00:00
# 2   7724  main_game  2009-09-15 00:00:00
# 3  24958  main_game  2009-02-15 00:00:00
# 4  11987  main_game  2006-05-18 00:00:00
#
#                                          game_modes  \
# 0  ['Single player', 'Multiplayer', 'Split screen']
# 1  ['Single player', 'Multiplayer', 'Split screen']
# 2                                 ['Single player']
# 3                                 ['Single player']
# 4                                 ['Single player']
#
#                            genres                         name  \
# 0  ['Platform', 'Sport', 'Indie']                       #IDARB
# 1  ['Platform', 'Sport', 'Indie']                       #IDARB
# 2              ['Music', 'Indie']                     .detuned
# 3          ['Adventure', 'Indie']                        .flow
# 4          ['Role-playing (RPG)']  .hack//G.U. Vol. 1: Rebirth
#
# ...

# %% [markdown]
# # 1. Definición de funciones

# %% [markdown]
# En este punto iremos definiendo las funciones que más adelante emplearemos en el análisis previo y en la limpieza de datos.

# %% [markdown]
# ## 1.1. Definición de variables

# %% [markdown]
# - Variable `age_rating`.

# %%
def age_cols(row):

    if row is None or pd.isnull(row):
        return np.NaN
    rts = ast.literal_eval(row)
    if isinstance(rts, dict):
        rts = [rts]
    rts = {rat['rating'][:4]: int(rat['rating'][5:]) for rat in rts}
    if 'PEGI' in rts.keys():
        return rts['PEGI']
    return rts['ESRB']

# %% [markdown]
# - Variable `franchises`.

# %%
def franchise_col(row):

    if pd.isnull(row):
        return []
    data = ast.literal_eval(row)
    franchises = []
    for franchise in data:
        if isinstance(franchise, dict):
            franchises.append(franchise['name'])
        else:
            franchises.append(franchise)
    return list(set(franchises))

# %% [markdown]
# - Variable `advanced_devs`.

# %%
def dev_col(row):

    if pd.isnull(row):
        return []
    data = ast.literal_eval(row)
    devs = []
    countries = []
    for dev in data:
        devs.append(dev['name'])
        if 'country' in dev.keys():
            countries.append(dev['country'])
    return list(set(devs)), list(set(countries))

# %% [markdown]
# - Variable `publishers`.

# %%
def pub_col(row):

    if pd.isnull(row):
        return []
    data = ast.literal_eval(row)
    pubs = [pub['name'] for pub in data]
    return list(set(pubs))

# %% [markdown]
# - Variable `RAWG_nrewiews`.

# %%
def rawg_rat(row):

    if pd.isnull(row):
        return 0
    reviews = ast.literal_eval(row)
    return sum(reviews.values())

# %% [markdown]
# - La variable `keywords` requiere definir más de una función.

# %%
# Se define una lista de keywords que no deberan aparecer en los resultados

banned_keys = [
    'digital distribution', 'steam', 'achievements', 'steam achievements',
    'playstation trophies', 'bink video', 'sequel', 'steam trading cards',
    'gog.com', 'xbox live', 'greatest hits', 'platform exclusive',
    'steam cloud', 'downloadable content', 'games on demand', 'ps3',
    'playstation network', 'playstation plus',
    'xbox one backwards compatibility', 'switch', 'virtual console',
    'direct2drive', 'fantasy', 'sci-fi', 'role playing', 'adventure',
    'strategy', 'platformer', 'action-adventure', 'shooter', 'remake',
    'compilation', 'hack and slash', 'launch titles', 'arcade', 'porting',
    'xbox one x enhanced', 'simulation', 'driving/racing',
    'top-down perspective'
    ]

# %%
def keyword_explosion(d_f, fixed_col):
    '''
    Se obtiene la cuenta total de cada keyword en funcion de los grupos
    buscados
    '''
    return (
        d_f[fixed_col + ['keywords']]
        .explode('keywords')
        .dropna()
        .value_counts()
        .reset_index()
        .rename(columns={0: 'count'})
        )

# %%
def get_new_keywords(keywords, genres, themes, keys, n=6):
    '''
    Se define el numero de keywords que tendra cada juego, y se rellena en
    funcion de las mas usadas por genero y tematica. Se excluiran aquellas que
    esten en la lista de baneadas
    '''
    keywords = [keyword for keyword in keywords if keyword not in banned_keys]
    while len(keywords) < n:
        to_add = (
            keys[0].loc[
                (keys[0]['genres'] == genres) &
                (keys[0]['themes'] == themes),
                'keywords'
            ]
            .tolist()
        )
        for i in range(n):
            try:
                if to_add[i] not in keywords:
                    keywords.append(to_add[i])
            except IndexError:
                break
        to_add = (
            keys[1].loc[keys[1]['genres'] == genres, 'keywords'].tolist()
        )
        for i in range(n):
            try:
                if to_add[i] not in keywords:
                    keywords.append(to_add[i])
            except IndexError:
                break
        to_add = keys[2]['keywords'].tolist()
        for i in range(6):
            if to_add[i] not in keywords:
                keywords.append(to_add[i])
    return keywords[:n]

# %% [markdown]
# - Variable: `OC_rating`.

# %%
#  Para la col solicitada, se obtiene el topx juegos segun su OC_rating con un mínimo min_games de juegos

def get_top(d_f, col, topx, min_games):
    
    return (
        d_f
        .explode(col)
        .groupby(col, as_index=False)
        ['OC_rating']
        .agg(['max', 'count'])
        .reset_index()
        .loc[lambda df: df['count'] > min_games]
        .sort_values(['max', 'count'], ascending=False)
        .iloc[:topx, 0]
        .tolist()
        )

# %% [markdown]
# ## 1.2 Definiciones de moda y One Hot Encoding

# %% [markdown]
# - Empezando por la moda:

# %%
#  Obtiene la moda de un DataFrame para la columna solicitada y agrupando con las columnas dadas

def get_mode(d_f, fixed_col, col):
  
    return (
        d_f
        .groupby(fixed_col + [col])
        [col]
        .agg(['count', 'max'])
        .sort_values(fixed_col + ['count'])
        .reset_index()
        .drop_duplicates(fixed_col)
        .drop(['count', 'max'], axis=1)
        )

# %%
# Se obtienen los 3 valores necesarios para rellenar la funcion de merge_mode

def obtain_mode_df(d_f, col):
  
    genre_theme_df = get_mode(d_f, ['genres', 'themes'], col)
    genre_df = get_mode(d_f, ['genres'], col)
    mode = d_f[col].value_counts().index[0]

    return genre_theme_df, genre_df, mode

# %%
# Se rellenan los valores nulos con la moda

def merge_mode(value_col, genres, themes, genre_theme_df, genre_df, mode):
  
    if not pd.isnull(value_col):
        return value_col
    sp_df = genre_theme_df.loc[
        (genre_theme_df['genres'] == genres) &
        (genre_theme_df['themes'] == themes)
        ]
    if len(sp_df) == 1:
        return sp_df.iloc[0, -1]
    sp_df = genre_df.loc[genre_df['genres'] == genres]
    if len(sp_df) == 1:
        return sp_df.iloc[0, -1]
    return mode

# %%
# Realiza el proceso anterior completo

def fill_mode(d_f, col):
 
    genre_theme_df, genre_df, mode = obtain_mode_df(d_f, col)
    return (
        d_f
        .apply(
            lambda x: merge_mode(
                x[col], x['genres'], x['themes'],
                genre_theme_df, genre_df, mode
                ),
            axis=1
            )
        )

# %% [markdown]
# - Ahora pasamos al **one hot**. Por un lado se define la herramienta capaz de realizar one_hot_encoding en funcion de los valores que haya en una lista

# %%
mlb = MultiLabelBinarizer(sparse_output=True)

# %% [markdown]
# Por otro lado, se definen las funciones siguiendo las pautas ya vistas en la moda anteriormente.

# %%
# Se transforma una columna que contenga listas a one hot encoding

def col_onehot(d_f, col):
  
    return d_f.join(
          pd.DataFrame
          .sparse
          .from_spmatrix(
              mlb.fit_transform(d_f.pop(col)),
              index=d_f.index,
              columns=mlb.classes_
                  )
          )

# %%
# Obtiene la media de un DataFrame para la columna solicitada y agrupando con las columnas dadas

def get_mean(d_f, fixed_col, col, roundng):

    if roundng:
        return round(d_f.groupby(fixed_col, as_index=False)[col].mean(), 0)
    return d_f.groupby(fixed_col, as_index=False)[col].mean()

# %%
# Se obtienen los 3 valores necesarios para rellenar la funcion de merge_mean

def obtain_mean_df(d_f, col, roundng):
   
    genre_theme_df = get_mean(d_f, ['genres', 'themes'], col, roundng).dropna()
    genre_df = get_mean(d_f, ['genres'], col, roundng).dropna()
    if roundng:
        mean = int(d_f[col].mean())
    else:
        mean = d_f[col].mean()

    return genre_theme_df, genre_df, mean

# %%
# Se rellenan los valores nulos con la media

def merge_mean(value_col, genres, themes, genre_theme_df, genre_df, mean):

    if not pd.isnull(value_col):
        return value_col
    sp_df = genre_theme_df.loc[
        (genre_theme_df['genres'] == genres) &
        (genre_theme_df['themes'] == themes)
        ]
    if len(sp_df) == 1:
        return sp_df.iloc[0, -1]
    sp_df = genre_df.loc[genre_df['genres'] == genres]
    if len(sp_df) == 1:
        return sp_df.iloc[0, -1]
    return mean

# %%
# Realiza el proceso anterior completo

def fill_mean(d_f, col, roundng=True):
 
    genre_theme_df, genre_df, mean = obtain_mean_df(d_f, col, roundng)
    return (
        d_f
        .apply(
            lambda x: merge_mean(
                x[col], x['genres'], x['themes'],
                genre_theme_df, genre_df, mean
                ),
            axis=1
            )
        )

# %% [markdown]
# # 2. Análisis previo

# %% [markdown]
# Vamos a volver a poner el dataset inicial para recordar los puntos que se explicarán despues.

# %%
games_df

# %% [markdown]
# Como podemos observar, la mayoría de variables aportan información adiciona al videojuego en cuestión por lo que se hará un estudio si de verdad aportan información o se elimina del dataframe.
#
# Por otro lado, para comparar simultáneamente datos principales del mismo videojuego con otras bases, se ha incluido en este dataframe diferentes páginas web de review:
#
# - HowLongToBeat.com
#
# - rawg.io
#
# - OpenCritic
#
# - MetaCritic

# %% [markdown]
# Antes de empezar, hay un valor en concreto que nos preocupa que este duplicados que es el del `id` puesto que a simple vista al observar los primeros datos del dataframe **ya observamos duplicados en su columna**. Teóricamente, no nos interesa tener juegos repetidos porque es dar la misma información repetida.

# %%
games_df['id'] = games_df['id'].astype(int)
games_df = (
        games_df
        .groupby('id', as_index=False)
        .agg({'platforms': lambda x: x.tolist()})
        .merge(
            games_df.drop('platforms', axis=1).drop_duplicates('id'),
            on='id'
            )
        )

# %% [markdown]
# Ahora observamos la información principal de todas las variables

# %%
games_df.info()

# %% [markdown]
# Vemos que todas las variables son `object` **cuando no debería ser así**:
#
# - `main_duration`, `extra_duration` y `comp_duration` son variables tiempo por lo que deben ser float.
#
# - Lo mismo ocurre con todas las relacionadas con las valoraciones numéricas, es decir, `OC_rating`, `OC_nreviews`, `MC_rating`, `RAWG_rating` que serán float.
#
# - `HLTB_equal_name` y `OC_equal_name` necesariamente deben ser booleanas al solo poder ser True o False.
#
# Por ello se procede a modificar los tipos de todas esas variables.

# %%
duration_col = [col for col in games_df if col.endswith('duration')]
rating_col = [col for col in games_df if col.endswith('rating')]
for col in duration_col + rating_col:
    games_df[col] = games_df[col].astype(float)
dates_col = [col for col in games_df if 'date' in col]
for col in dates_col:
    games_df[col] = pd.to_datetime(games_df[col]).dt.year

# %%
games_df.info()

# %% [markdown]
# Ahora procedemos con los valores nulos

# %%
games_df.isna().mean()*100
# Out:
# id                       0.0
# category                 0.0
# first_release_date       0.0
# game_modes               0.0
# genres                   0.0
# name                     0.0
# platforms                0.0
# player_perspectives      0.0
# summary                  0.0
# themes                   0.0
# updated_at               0.0
# storyline                0.0
# status                   0.0
# age_ratings              0.0
# release_dates            0.0
# keywords                 0.0
# game_engines             0.0
# franchises               0.0
# ports                    0.0
# remakes                  0.0
# parent_game              0.0
# remasters                0.0
# expanded_games           0.0
# standalone_expansions    0.0
# expansions               0.0
# bundles                  0.0
# developer                0.0
# porting                  0.0
# publisher                0.0
# supporting               0.0
# n_count                  0.0
# HLTB_equal_name          0.0
# ...

# %% [markdown]
# Es curioso que viendo que al visualizar el dataframe salgan valores nulos (por ejemplo en `story_line` o `MC_rating`) luego al hacer el conteo no salga ninguna. Eso se deberá a que **lo está tomando como texto (string)** por lo que vamos a convertirlos en los verdaderos valores nulos que son.

# %%
games_df = games_df.replace(['nan', 'None', '[]', '{}'], np.NaN)

# %%
games_df.isna().mean()*100
# Out:
# id                        0.000000
# category                  0.000000
# first_release_date        0.000000
# game_modes                2.864302
# genres                    0.513413
# name                      0.000000
# platforms                 0.000000
# player_perspectives      11.791294
# summary                   0.198978
# themes                   10.717795
# updated_at                0.000000
# storyline                69.838852
# status                   97.938980
# age_ratings              30.166061
# release_dates             0.000000
# keywords                  8.718188
# game_engines             72.364154
# franchises               45.359634
# ports                    86.491599
# remakes                  96.528938
# parent_game              92.812224
# remasters                96.570699
# expanded_games           96.278373
# standalone_expansions    98.749632
# expansions               87.751793
# bundles                  73.847892
# developer                 3.812518
# ...

# %% [markdown]
# Ahora ya aparecen bien recogidos todos los valores nulos.

# %% [markdown]
# # 3. Eliminación de las variables

# %% [markdown]
# De este análisis de valores nulos observamos ciertas variables con excesivos valores nulos incluso algunos por encima del 90%. Vamos a hacer un análisis de cada caso, empezando por aquellas que superan el 47% de valores nulos.
#
# - `storyline`: se decide eliminarla porque aunque no tiene un porcentaje lo suficientemente alto como otras por un lado no se puede eliminar sus valores nulos ya que modificaría considerablemente las dimensiones del dataframe; y por otro lado tampoco existe la opción de rellenar esos valores nulos con otros al ser todo texto con muchas palabras diferentes. Además existe la variable `summary` que incluye la historia principal.
#
# - `status`: con un 98% de valores nulos se decide eliminarla del dataframe.
#
# - `age_ratings`: no tiene un porcentaje lo suficientemente alto como para eliminarla. Esta variable por un lado indica la edad recomendada (aunque en el sistema americano no se usan números sino letras) acompañado de otros términos que lo justifican. Se decide centrarse solo en la edad, y a partir de ella, rellenar los valores nulos con la moda. Como nos interesa el mercado europeo, transformaremos lo indicado en ESRB (el sistema americano) con el PEGI (sistema europeo).
#
# - `porting`: con un 90% de valores nulos se decide eliminarla del dataframe.
#
# - `supporting`: con un 96% de valores nulos se decide eliminarla del dataframe.
#
# - `game_engines`: se decide eliminarla porque aunque no tiene un porcentaje lo suficientemente alto como otras por un lado no se puede eliminar sus valores nulos ya que modificaría considerablemente las dimensiones del dataframe; y por otro lado tampoco existe la opción de rellenar esos valores nulos con otros (como sería con la moda) por la cantidad de motores recogidos.
#
# - `parent_game`: con un 93% de valores nulos se decide eliminarla del dataframe.
#
# - `remakes`: con un 96% de valores nulos se decide eliminarla del dataframe. Además, realmente en muchos casos esta información ya es recogida en la variable `category`.
#
# - `remasters`: con un 96% de valores nulos se decide eliminarla del dataframe. Además, realmente en muchos casos esta información ya es recogida en la variable `category`
#
# - `ports`: más allá de su porcentaje elevado de valores nulos, esta variable está fuertemente relacionada con `porting` por lo que al eliminar dicha variable esta pierde aún más sentido en cuanto a información aportada.
#
# - `bundles`: se decide eliminarla porque aunque no tiene un porcentaje lo suficientemente alto como otras por un lado no se puede eliminar sus valores nulos ya que modificaría considerablemente las dimensiones del dataframe; y por otro lado tampoco existe la opción de rellenar esos valores nulos con otros (como sería con la moda) por la cantidad de paquetes distintos (y lo que implica en franquicias y compañias se refiere) hay.
#
# - `standalone_expansions`: con un 98% de valores nulos se decide eliminarla del dataframe.
#
# - `expanded_games`: con un 96% de valores nulos se decide eliminarla del dataframe.
#
# - `expansions`: más allá de su porcentaje elevado de valores nulos, si se ha eliminado `expanded_games` que en bastantes ocasiones incluye contenido de esta variable, menos sentido tiene mantenerla.
#
# - Todas las variables relacionadas con la página web OpenCritic (`OC_rating`, `OC_nreviews`, `OC_name` y `OC_link`) con más de un 60% de valores nulos se decide eliminarlas del dataset final. Se planteó la posibilidad de salvar la variable de `OC_rating` pero tras varias pruebas se decidió que era muy compleja de rellenar correctamente así que sumado a su porcentaje de valores nulos también se decidió elimina

# %% [markdown]
# Aparte de los valores nulos mencionados, aunque las siguientes variables no tienen un excesivo número de valores nulos se decide obviarlas del dataset final por no aportar realmente información de cara a desarrollar el algoritmo:
#
# - `HLTB_link`: sirven únicamente para realizar la conexión. No aportan ninguna información más.
#
# - `category`: aunque en cierta medida aporta información al indicar si es un juego principal o alguna variación de este (remakes, ports...) de cara al algoritmo puede resultar peligroso que si te guste un remake luego solo te recomiende esa clase de juegos obviando los otros.
#
# - `updated_at`: la última fecha de actualización tampoco aportaba información importante.
#
# - `n_count`: esta variable se creó para localizar los juegos en otras páginas pero nada tiene que apoerar al algoritmo.
#
# - `devs`: existiendo la variable de `advanced_devs` que es más completa y ya incluye la información de la otra variable solo es información repetida para el algoritmo.
#
# - `HLTB_name` y `RAWG_name`: el nombre que tuvieran en dichas páginas poco importa existiendo ya la variable `name`.

# %% [markdown]
# Así que una vez dadas todas las principales explicaciones se procede a la limpieza de todas las columnas y su posterior One Hot Encoding tras las definiciones y análisis previo ya realizado.

# %%
def g_cleaner(games_df):
    
    # Se eliminan de manera directa aquelals variables ya explicadas
    
    games_df = (
        games_df
        .drop([
            'bundles', 'category', 'devs', 'expanded_games', 'expansions',
            'game_engines', 'HLTB_link', 'HLTB_name', 'n_count', 'OC_link',
            'OC_name', 'OC_nreviews', 'parent_game', 'porting', 'ports',
            'RAWG_name', 'release_dates', 'remakes', 'remasters',
            'standalone_expansions', 'status', 'storyline', 'supporting',
            'updated_at'
            ],
            axis=1
            )
        )
 
    # Se limpian aquellos con datos incorrectos de RAWG, pues no se lograria un
    # correcto cruce con las reviews
    games_df = (
        games_df
        .loc[games_df['RAWG_equal_name'] == 'True']
        .drop('RAWG_equal_name', axis=1)
        )

    # Se borran los valores nulos de las columnas que lo permiten dado su
    # infimo porcentaje y eliminamos la columna, pues no podra ser utilizada en
    # el desarrollo del algoritmo
    print('Comienza el tratamiento del dataset')

    games_df.dropna(subset=['summary'], inplace=True)
    games_df.drop('summary', axis=1, inplace=True)

    # Se limpian las columnas que sean necesarias
    games_df['age_ratings'] = games_df['age_ratings'].map(age_cols)
    games_df['franchises'] = games_df['franchises'].map(franchise_col)
    games_df = games_df.reset_index(drop=True)
    games_df['developer'] = games_df['developer'].fillna('[]')
    games_df['publisher'] = games_df['publisher'].fillna('[]')
    games_df[['developer', 'country']] = pd.DataFrame(
        games_df['developer'].map(dev_col).tolist()
        )
    games_df['publisher'] = games_df['publisher'].map(pub_col)
    games_df['RAWG_nreviews'] = games_df['RAWG_nreviews'].map(rawg_rat)
    games_df['devs'] = (
        games_df['advanced_devs'].fillna('[]').map(ast.literal_eval)
        )
    games_df.drop('advanced_devs', axis=1, inplace=True)
    games_df = games_df.loc[games_df['RAWG_nreviews'] > 0]

    # Se tratan los ratings llenando los datos nulos de OC con los de MC, e
    # iterando para el resto
    print('Se obtienen los ratings')
    games_df.loc[games_df['OC_equal_name'] != 'True', 'OC_rating'] = np.NaN
    games_df['OC_rating'] = games_df['OC_rating'].replace(0, np.NaN)
    games_df['OC_rating'] = (
        games_df['OC_rating']
        .fillna(
            round(
                games_df['MC_rating'] /
                (games_df['MC_rating'].mean() / games_df['OC_rating'].mean()),
                0
                )
            )
        )

    games_df['OC_rating'] = fill_mean(games_df, 'OC_rating')
    games_df.drop(['MC_rating', 'OC_equal_name'], axis=1, inplace=True)

    # Se aplican la funcion de moda a las columnas requeridas
    for col in ['age_ratings', 'game_modes', 'player_perspectives']:
        games_df[col] = fill_mode(games_df, col)

    # Se tratan las keywords
    print('Se tratan las keywords')
    games_df['keywords'] = (
        games_df['keywords'].fillna('[]').map(ast.literal_eval)
        )

    key_count = []
    for cols in [['genres', 'themes'], ['genres'], []]:
        key_count.append(
            keyword_explosion(games_df, cols)
            .loc[lambda df: ~(df['keywords'].isin(banned_keys))]
            )

    games_df['keywords'] = games_df.apply(
        lambda x: get_new_keywords(
            x['keywords'], x['genres'], x['themes'], key_count
            ),
        axis=1)

    # Se trata los datos de duracion
    print('Se trata la duracion')
    games_df.loc[games_df['HLTB_equal_name'] != 'True', duration_col] = np.NaN
    games_df.drop('HLTB_equal_name', axis=1, inplace=True)
    games_df[duration_col] = games_df[duration_col].replace(0, np.NaN)
    for col in duration_col:
        games_df[col] = fill_mean(games_df, col, False)

    # Se tratan los devs para quedarnos unicamente con los que esten en las
    # posiciones de director, escritor, disenador o productor
    print('Se tratan los devs')
    games_df['devs'] = games_df['devs'].map(
        lambda devs: [
            dev['Name'] for dev in devs
            if dev['Position'][0] in [
                    'director', 'writer', 'designer', 'producer'
                    ]
            ]
        )

    # Para ciertas columnas, solo se conservara un top de variables, de
    # cara a no dejar un one_hot_encoding de muchas columnas
    # Este top se hará por los juegos con una mejor nota segun los nuevos
    # valores de OC y con un minimo de juegos
    print('Se obtienen los valores top')
    col_top = [
        'developer', 'publisher', 'keywords', 'devs', 'franchises', 'country'
        ]
    for col, topx, min_games in zip(
            col_top,
            [50, 50, 200, 100, 100, 15],
            [5, 5, 10, 5, 2, 10]):
        games_df = (
            games_df
            .drop(col, axis=1)
            .merge(
                games_df
                .explode(col)
                .loc[lambda df: df[col].isin(
                    get_top(games_df, col, topx, min_games)
                    )]
                .groupby('id', as_index=False)
                [col]
                .agg(lambda x: x.tolist()),
                on='id',
                how='left'
                )
            )

    # Se pasan las variables a one_hot_encoding
    print('Se realiza el one_hot_encoding')
    col_hot = ['game_modes', 'player_perspectives']
    for col in col_hot:
        games_df[col] = games_df[col].map(ast.literal_eval)
        cols = games_df.columns
        games_df = col_onehot(games_df, col)
        games_df = games_df.rename(columns={
            f'{col_name}': f'{col_name}_{col}'
            for col_name in games_df if col_name not in cols
            })

    # Se pasan las variables con valores nulos a one_hot_encoding
    col_nan = ['genres', 'themes']
    for col in col_nan:
        games_df[col] = games_df[col].fillna('[]').map(ast.literal_eval)
        cols = games_df.columns
        games_df = col_onehot(games_df, col)
        games_df = games_df.rename(columns={
            f'{col_name}': f'{col_name}_{col}'
            for col_name in games_df if col_name not in cols
            })

    # Se pasan las variables restantes a one_hot_encoding
    for col in col_top:
        games_df[col] = games_df[col].map(
            lambda x: x if isinstance(x, list) else []
            )
        cols = games_df.columns
        games_df = col_onehot(games_df, col)
        games_df = games_df.rename(columns={
            f'{col_name}': f'{col_name}_{col}'
            for col_name in games_df if col_name not in cols
            })

    # Se crea un array de las columnas de one_hot
    for col_name in col_top + col_nan + col_hot:
        cols_to_treat = [col for col in games_df if col.endswith(col_name)]
        games_df[col_name] = games_df[cols_to_treat].values.tolist()
        games_df.drop(cols_to_treat, axis=1, inplace=True)

    # Se devuelve el dataset limpio previo a la limpieza de las reviews
    print('Primera limpieza completada')
    return games_df

# %%
g_cleaner(games_df)

# %% [markdown]
# Se procede a guardar tanto en formato csv como feather.

# %%
games_df.to_csv("Games.csv")

# %%
games_df.to_csv("Games.csv")

# %% [markdown]
# # 3. Gráficos

# %% [markdown]
# A modo visual, se procede a crear los gráficos de aquellas variables más influyentes en el algoritmo cuyos valores nulos se han ido rellenado. Las tres primeras variables que se mostraran (`games_mode`, `player_perspectives` y `themes`) al haber sido sus valores nulos sustituidos por la moda se prentende mostrar **qué valor ha sido el más destacado y por el cual ha sustituido los valores nulos**.
#
# Respecto a `OC_rating` donde se aplicó la media en vez de la moda, la intención con el gráfico es desmotrar que aunque las notas van del 0 al 100, **las valoraciones más destacadas rondan entre el 80-70 de valorción**.

# %% [markdown]
# - Variable `games_mode`:

# %%
games_mode = games_df['game_modes'].value_counts().sort_values(ascending=False)

games_mode.plot(kind="bar", figsize=(13,7), color = "orange")
plt.title("Moda de la variable games_mode", y = 1.05, size = 19)
plt.xlim(0,7)
plt.xlabel('Tipos de modo', size = 14)
plt.ylabel('Nº de observaciones', size = 14)

# %% [markdown]
# - Variable `player_perspectives`:

# %%
perspective = games_df['player_perspectives'].value_counts().sort_values(ascending=False)

perspective.plot(kind="bar", figsize=(13,7), color = "blue")
plt.title("Moda de la variable player_perspectives", y = 1.05, size = 19)
plt.xlim(0,10)
plt.xlabel('Tipos de perspectiva del jugador', size = 14)
plt.ylabel('Nº de observaciones', size = 14)

# %% [markdown]
# - Variable `themes`:

# %%
themes = games_df['themes'].value_counts().sort_values(ascending=False)

themes.plot(kind="bar", figsize=(13,7), color = "green")
plt.title("Moda de la variable themes", y = 1.05, size = 19)
plt.xlim(0,15)
plt.xlabel('Tipos de tema', size = 14)
plt.ylabel('Nº de observaciones', size = 14)

# %% [markdown]
# - Variable `OC_rating`:

# %%
rating = games_df['OC_rating'].value_counts().sort_values(ascending=False)

rating.plot(kind="bar", figsize=(50,15), color = "red")
plt.title("OC_rating", y = 1.05, size = 35)
# Se parte del 1 en el límite del eje X al ser el mayor valor el 0 que no aporta aquí información
plt.xlim(1,40)
plt.ylim(0,200)
plt.xlabel('Notas', size = 30)
plt.xticks(size = 25, rotation = 20) 
plt.ylabel('Nº de observaciones', size = 30)
